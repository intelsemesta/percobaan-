# %% [markdown]
# <h1>Operator Aitmatika</h1>

# %%
x = int(input("Isikan nilai x :"))
y = int(input("Isikan nilai y :"))

hasilTambah = x + y
hasilKurang = x - y
hasilKali = x * y
hasilBagi = x / y
hasilModulus = x % y
hasilPangkat = x ** y
hasilBagiBulat = x // y

print("Penjumlahan ", x, "+", y, "=", hasilTambah)
print("Pengurangan ", x, "-", y, "=", hasilKurang)
print("Perkalian ", x, "*", y, "=", hasilKali)
print("Pembagian ", x, "/", y, "=", hasilBagi)
print("Sisa Bagi ", x, "%", y, "=", hasilModulus)
print("Pangkat ", x, "^", y, "=", hasilPangkat)
print("Pembagian Bulat ", x, "//", y, "=", hasilBagiBulat)
# Out:
# Isikan nilai x : 10
# Isikan nilai y : 12
# Penjumlahan  10 + 12 = 22
# Pengurangan  10 - 12 = -2
# Perkalian  10 * 12 = 120
# Pembagian  10 / 12 = 0.8333333333333334
# Sisa Bagi  10 % 12 = 10
# Pangkat  10 ^ 12 = 1000000000000
# Pembagian Bulat  10 // 12 = 0

# %% [markdown]
# <h1>Operator Assingment</h1>

# %%
nilai = int(input ("Isikan Nilai :"))
print("Nilai awal dari <nilai> :", nilai)
nilai+=3
print("Nilai setelah ditambahkan 3:", nilai)
nilai-=5      
print("Nilai setelah dikurangkan 5:", nilai)
nilai*=10
print("Nilai setelah dikalikan 10:", nilai)
nilai/=2
print("Nilai setelah dibagi 2:", nilai)
# Out:
# Isikan Nilai : 10
# Nilai awal dari <nilai> : 10
# Nilai setelah ditambahkan 3: 13
# Nilai setelah dikurangkan 5: 8
# Nilai setelah dikalikan 10: 80
# Nilai setelah dibagi 2: 40.0

# %% [markdown]
# <h1>Operator</h1>

# %%
val1 = int(input('Isikan Nilai 1:'))
val2 = int(input('Isikan Nilai 2:'))

print("Apakah ",val1,"=",val2,"?:",val1==val2)
print("Apakah ",val1,"!=",val2,"?:",val1!=val2)
print("Apakah ",val1,">",val2,"?:",val1>val2)
print("Apakah ",val1,">=",val2,"?:",val1>=val2)
print("Apakah ",val1,"<",val2,"?:",al1<val2)
print("Apakah ",val1,"<=",val2,"?:",val1<=val2)
# Out:
# Isikan Nilai 1: 1
# Isikan Nilai 2: 2
# Apakah  1 = 2 ?: False
# Apakah  1 != 2 ?: True
# Apakah  1 > 2 ?: False
# Apakah  1 >= 2 ?: False
# Apakah  1 < 2 ?: True
# Apakah  1 <= 2 ?: True

# %%
a = int(input('Isikan nilai a:')) 
b = int(input('Isikan nilai b:')) 
c = int(input('Isikan nilai c:')) 
d = int(input('Isikan nilai d:')) 
print("Nilai a:", a)
print("Nilai b:", b)
print("Nilai c:", c)
print("Nilai d:", d)

print("Apakah a > b dan c < d?" , a > b and c < d) #logika and
print("Apakah a > b atau c < d?" , a > b or c < d) #logika or
print("Apakah a > b dan c < d?" , not (a > b and c < d)) #not and
# Out:
# Isikan nilai a: 1
# Isikan nilai b: 2
# Isikan nilai c: 3
# Isikan nilai d: 4
# Nilai a: 1
# Nilai b: 2
# Nilai c: 3
# Nilai d: 4
# Apakah a > b dan c < d? False
# Apakah a > b atau c < d? True
# Apakah a > b dan c < d? True

# %%
num1 = "10"
num2 = 10
num3 = num2

print("Memori address dari num1", id(num1))
print("Memori address dari num2", id(num1))
print("Memori address dari num3", id(num1))

print("Apakah num1 adalah num2",num1 is num2)
print("Apakah num1 adalah num3",num2 is num3)
print("Apakah num2 bukan num3",num2 is not num3)
# Out:
# Memori address dari num1 1727309212496
# Memori address dari num2 1727309212496
# Memori address dari num3 1727309212496
# Apakah num1 adalah num2 False
# Apakah num1 adalah num3 True
# Apakah num2 bukan num3 False

# %%
nama = input("Isikan nama yang dicari:")
listNama = ["Andi","Budi","Caca","Dudi","Erfan"]
print(nama in listNama)
print(nama in listNama[0])
print(nama not in listNama)
print(nama not in listNama[0])
# Out:
# Isikan nama yang dicari: Caca
# True
# False
# False
# True

# %%
bil1 = int(input("Isikan bilangan 1:"))
bil2 = int(input("Isikan bilangan 2:"))

print("biner dari",bil1,":",bin(bil1))
print("biner dari",bil2,":",bin(bil2))
#bitwise &
bitwiseAnd = bil1 & bil2
print(bin(bil1))
print(bin(bil2))
print("-----------------&")
print(bin(bitwiseAnd))
print("Hasil desimalnya adalah:",bitwiseAnd)


#bitwise |
bitwiseOr = bil1 | bil2
print(bin(bil1))
print(bin(bil2))
print("-----------------|")
print(bin(bitwiseOr))
print("Hasil desimalnya adalah:",bitwiseOr)

#bitwise ^
bitwiseXOR = bil1 ^ bil2
print(bin(bil1))
print(bin(bil2))
print("-----------------^")
print(bin(bitwiseXOR))
print("Hasil desimalnya adalah:",bitwiseXOR)

#bitwise << shift left
bitwiseSL = bil1 << bil2
print(bin(bil1), "digeser ke kiri sebanyak",bil2,"bit")
print("Hasilnya adalah",bin(bitwiseSL))
print("Nilai desimalnya adalah",bitwiseSL)
print("-----------------<<")


#bitwise << shift right
bitwiseSR = bil1 >> bil2
print(bin(bil1), "digeser ke kanan sebanyak",bil2,"bit")
print("Hasilnya adalah",bin(bitwiseSR))
print("Nilai desimalnya adalah",bitwiseSR)
print("----------------->>")
# Out:
# Isikan bilangan 1: 2
# Isikan bilangan 2: 3
# biner dari 2 : 0b10
# biner dari 3 : 0b11
# 0b10
# 0b11
# -----------------&
# 0b10
# Hasil desimalnya adalah: 2
# 0b10
# 0b11
# -----------------|
# 0b11
# Hasil desimalnya adalah: 3
# 0b10
# 0b11
# -----------------^
# 0b1
# Hasil desimalnya adalah: 1
# 0b10 digeser ke kiri sebanyak 3 bit
# Hasilnya adalah 0b10000
# Nilai desimalnya adalah 16
# -----------------<<
# 0b10 digeser ke kanan sebanyak 3 bit
# Hasilnya adalah 0b0
# Nilai desimalnya adalah 0
# ----------------->>

# %%
number = int(input("Insert your number:"))
oddEven = "Bilangan Genap" if  number % 2==0 else "Bilangan Ganjil"
print(oddEven)
# Out:
# Insert your number: 2
# Bilangan Genap

# %%
Pisang = int(input("Isikan jumlah Pisang yang di beli:"))
Kolak = int(input("Isikan jumlah Kolak yang di beli:"))
Nasi_Padang = int(input("Isikan jumlah Nasi Padang yang di beli:"))
Es_Buah = int(input("Isikan jumlah Es Buah yang di beli:"))

print("Pisang :" ,Pisang,"=",Pisang * 13000)
print("Kolak :" ,Kolak,"=",Kolak * 5000)
print("Nasi_Padang :" ,Nasi_Padang ,"=",Nasi_Padang * 20000)
print("ES_Buah :" ,Es_Buah ,"=",Es_Buah * 10000)
total_belanja = (Pisang * 13000) + (Kolak * 5000) + (Nasi_Padang * 200000) + (Es_Buah * 10000)
print("total belanja =", total_belanja)
discount = 5 if total_belanja > 25000 else 0
total_bayar = total_belanja -(total_belanja * (discount/100))
print("Discount :" ,discount, "%")
print("Total bayar:",total_bayar)
# Out:
# Isikan jumlah Pisang yang di beli: 9
# Isikan jumlah Kolak yang di beli: 10
# Isikan jumlah Nasi Padang yang di beli: 0
# Isikan jumlah Es Buah yang di beli: 40
# Pisang : 9 = 117000
# Kolak : 10 = 50000
# Nasi_Padang : 0 = 0
# ES_Buah : 40 = 400000
# total belanja = 567000
# Discount : 5 %
# Total bayar: 538650.0
