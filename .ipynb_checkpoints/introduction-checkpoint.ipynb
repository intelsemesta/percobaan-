# %% [markdown]
# <center><img src="https://logos-world.net/wp-content/uploads/2021/10/Python-Logo.png" width="300"></center><br>
# Tutorial Jupiter Notebook<br>
# Tempat menuliskan kode disebut sebagai <b>cell</b><br>
# <ol>
#     <li>code - Y</ol>
#     <li>Markdown - M</li>
# </ol>
# <hr>
# cara menjalankan cell<br>
# <table>
#     <tr>
#         <td>command</td>
#         <td>Keterangan</td>
#     </tr>
#     <tr>
#         <td>ctrl + enter</td>
#         <td>Running dan fokus di cell aktif</td>
#     </tr>
#     <tr>
#         <td>shift + enter</td>
#         <td>Running dan fokus di cell berikutnya</td>
#     </tr>
# </table>

# %% [markdown]
# menambahkan cell ada 2 cara
# <ul>
#     <li>Tekan A -> Above</li>
#     <li>Tekan B -> Below</li>
# </ul>
# cara membuat output di python adalah <br>
# '''print (teks yang akan di print)'''

# %%
#Cetak tuliskan selamat belajar python
print ("selamat belajar python")
data = "selamat belajar variabel"
print(data)
# Out:
# selamat belajar python
# selamat belajar variabel

# %%
print(data)
data
3 + 2
num1 = 6 
num2 = 9
num3 = 2
num1 + num2 + num3
# Out:
# selamat belajar variabel
# 17
